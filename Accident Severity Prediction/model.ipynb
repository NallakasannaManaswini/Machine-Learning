# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("RTA Dataset.csv")

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
#  13  Road_allignment              12174 non-null  object
#  14  Types_of_Junction            11429 non-null  object
#  15  Road_surface_type            12144 non-null  object
#  16  Road_surface_conditions      12316 non-null  object
#  17  Light_conditions             12316 non-null  object
#  18  Weather_conditions           12316 non-null  object
#  19  Type_of_collision            12161 non-null  object
#  20  Number_of_vehicles_involved  12316 non-null  int64
#  21  Number_of_casualties         12316 non-null  int64
#  22  Vehicle_movement             12008 non-null  object
#  23  Casualty_class               12316 non-null  object
#  24  Sex_of_casualty              12316 non-null  object
#  25  Age_band_of_casualty         12316 non-null  object
#  26  Casualty_severity            12316 non-null  object
#  27  Work_of_casuality            9118 non-null   object
#  28  Fitness_of_casuality         9681 non-null   object
#  29  Pedestrian_movement          12316 non-null  object
#  30  Cause_of_accident            12316 non-null  object
#  31  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(30)
# memory usage: 3.0+ MB

# %%
print(df['Accident_severity'].isna().sum())
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
df.drop(columns={'Service_year_of_vehicle','Defect_of_vehicle','Work_of_casuality','Casualty_class','Sex_of_casualty','Age_band_of_casualty','Casualty_severity','Fitness_of_casuality'},inplace=True)

# %%
a=pd.to_datetime(df['Time'],format='%H:%M:%S',errors='coerce')
df['Hours']=a.dt.hour
df['Mins']=a.dt.minute

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured  ... Weather_conditions  \
# 0            Owner     Residential areas  ...             Normal
# 1            Owner          Office areas  ...             Normal
# 2            Owner    Recreational areas  ...             Normal
# 3     Governmental          Office areas  ...             Normal
# 4            Owner      Industrial areas  ...             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident Accident_severity  Hours  Mins
# 0             Moving Backward     Slight Injury     17     2
# 1                  Overtaking     Slight Injury     17     2
# 2   Changing lane to the left    Serious Injury     17     2
# 3  Changing lane to the right     Slight Injury      1     6
# 4                  Overtaking     Slight Injury      1     6
#
# [5 rows x 26 columns]

# %%
h=df[['Hours','Mins']]

# %%
h.head()
# Out:
#    Hours  Mins
# 0     17     2
# 1     17     2
# 2     17     2
# 3      1     6
# 4      1     6

# %%
df.drop(columns=['Hours','Mins','Time'],inplace=True)

# %%
df.head()
# Out:
#   Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      Monday              18-30          Male   Above high school
# 1      Monday              31-50          Male  Junior high school
# 2      Monday              18-30          Male  Junior high school
# 3      Sunday              18-30          Male  Junior high school
# 4      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  ...  \
# 0            Owner     Residential areas                NaN  ...
# 1            Owner          Office areas  Undivided Two way  ...
# 2            Owner    Recreational areas              other  ...
# 3     Governmental          Office areas              other  ...
# 4            Owner      Industrial areas              other  ...
#
#   Road_surface_conditions       Light_conditions Weather_conditions  \
# 0                     Dry               Daylight             Normal
# 1                     Dry               Daylight             Normal
# 2                     Dry               Daylight             Normal
# 3                     Dry  Darkness - lights lit             Normal
# 4                     Dry  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement  Pedestrian_movement  \
# 0                    2   Going straight     Not a Pedestrian
# 1                    2   Going straight     Not a Pedestrian
# 2                    2   Going straight     Not a Pedestrian
# 3                    2   Going straight     Not a Pedestrian
# 4                    2   Going straight     Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 23 columns]

# %%
df=pd.concat([h,df],axis=1)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday              18-30          Male
# 1     17     2      Monday              31-50          Male
# 2     17     2      Monday              18-30          Male
# 3      1     6      Sunday              18-30          Male
# 4      1     6      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  object
#  3   Age_band_of_driver           12316 non-null  object
#  4   Sex_of_driver                12316 non-null  object
#  5   Educational_level            11575 non-null  object
#  6   Vehicle_driver_relation      11737 non-null  object
#  7   Driving_experience           11487 non-null  object
#  8   Type_of_vehicle              11366 non-null  object
#  9   Owner_of_vehicle             11834 non-null  object
#  10  Area_accident_occured        12077 non-null  object
#  11  Lanes_or_Medians             11931 non-null  object
#  12  Road_allignment              12174 non-null  object
#  13  Types_of_Junction            11429 non-null  object
#  14  Road_surface_type            12144 non-null  object
#  15  Road_surface_conditions      12316 non-null  object
#  16  Light_conditions             12316 non-null  object
#  17  Weather_conditions           12316 non-null  object
#  18  Type_of_collision            12161 non-null  object
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12008 non-null  object
#  22  Pedestrian_movement          12316 non-null  object
#  23  Cause_of_accident            12316 non-null  object
#  24  Accident_severity            12316 non-null  object
# dtypes: int32(2), int64(2), object(21)
# memory usage: 2.3+ MB

# %%
df['Day_of_week'].unique()
# Out:
# array(['Monday', 'Sunday', 'Friday', 'Wednesday', 'Saturday', 'Thursday',
#        'Tuesday'], dtype=object)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday              18-30          Male
# 1     17     2      Monday              31-50          Male
# 2     17     2      Monday              18-30          Male
# 3      1     6      Sunday              18-30          Male
# 4      1     6      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %%
ages={
    'Under 18':0,
    '18-30':1,
    '31-50':2,
    'Over 51':3,
    'Unknown':-1
}

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday              18-30          Male
# 1     17     2      Monday              31-50          Male
# 2     17     2      Monday              18-30          Male
# 3      1     6      Sunday              18-30          Male
# 4      1     6      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Age_band_of_driver']=df['Age_band_of_driver'].map(ages)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Age_band_of_driver'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
#  1    4271
#  2    4087
#  3    1585
# -1    1548
#  0     825
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Sex_of_driver'].mode()
# Out:
# 0    Male
# Name: Sex_of_driver, dtype: object

# %%
df['Sex_of_driver']=df['Sex_of_driver'].apply(lambda x: 'Male' if x=='Unknown' else x)

# %%
df['Sex_of_driver'].value_counts()
# Out:
# Sex_of_driver
# Male      11615
# Female      701
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', nan,
#        'Elementary school', 'High school', 'Unknown', 'Illiterate',
#        'Writing & reading'], dtype=object)

# %%
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    7619
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Unknown                100
# Illiterate              45
# Name: count, dtype: int64

# %%
df['Educational_level']=df['Educational_level'].fillna(df['Educational_level'].mode()[0])

# %%
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    8360
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Unknown                100
# Illiterate              45
# Name: count, dtype: int64

# %%
df['Educational_level'].isna().sum()
# Out:
# np.int64(0)

# %%
def edu(val):
    if(val=='Unknown'):
        return "Junior high school"
    else:
        return val

# %%
df['Educational_level']=df['Educational_level'].apply(edu)

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', 'Elementary school',
#        'High school', 'Illiterate', 'Writing & reading'], dtype=object)

# %%
df['Educational_level'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12316 entries, 0 to 12315
# Series name: Educational_level
# Non-Null Count  Dtype
# --------------  -----
# 12316 non-null  object
# dtypes: object(1)
# memory usage: 96.3+ KB

# %%
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    8460
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Illiterate              45
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Vehicle_driver_relation'].value_counts()
# Out:
# Vehicle_driver_relation
# Employee    9627
# Owner       1973
# Other        123
# Unknown       14
# Name: count, dtype: int64

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %%
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].replace({'Unknown':'Employee'})

# %%
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].fillna('Employee')

# %%
df['Vehicle_driver_relation'].value_counts()
# Out:
# Vehicle_driver_relation
# Employee    10220
# Owner        1973
# Other         123
# Name: count, dtype: int64

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Owner', 'Other'], dtype=object)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Owner', 'Other'], dtype=object)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
df['Driving_experience']=df['Driving_experience'].fillna('unknown')

# %%
exp={
    'No Licence':0,
    'Below 1yr':1,
    '1-2yr':2,
    '2-5yr':3,
    '5-10yr':4,
    'Above 10yr':5,
    'unknown':-1
}

# %%
df['Driving_experience']=df['Driving_experience'].map(exp)

# %%
df['Driving_experience'].unique()
# Out:
# array([ 2,  5,  4,  3, -1,  0,  1])

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation  Driving_experience  \
# 0   Above high school                Employee                   2
# 1  Junior high school                Employee                   5
# 2  Junior high school                Employee                   2
# 3  Junior high school                Employee                   4
# 4  Junior high school                Employee                   3
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                  NaN            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# Automobile              3205
# Lorry (41?100Q)         2186
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Special vehicle           84
# Ridden horse              76
# Turbo                     46
# Bajaj                     29
# Bicycle                   21
# Name: count, dtype: int64

# %%
df['Type_of_vehicle']=df['Type_of_vehicle'].fillna('Other')

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', 'Other',
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Bajaj', 'Turbo', 'Motorcycle', 'Special vehicle',
#        'Bicycle'], dtype=object)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation  Driving_experience  \
# 0   Above high school                Employee                   2
# 1  Junior high school                Employee                   5
# 2  Junior high school                Employee                   2
# 3  Junior high school                Employee                   4
# 4  Junior high school                Employee                   3
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                Other            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  object
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  object
#  5   Educational_level            12316 non-null  object
#  6   Vehicle_driver_relation      12316 non-null  object
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  object
#  9   Owner_of_vehicle             11834 non-null  object
#  10  Area_accident_occured        12077 non-null  object
#  11  Lanes_or_Medians             11931 non-null  object
#  12  Road_allignment              12174 non-null  object
#  13  Types_of_Junction            11429 non-null  object
#  14  Road_surface_type            12144 non-null  object
#  15  Road_surface_conditions      12316 non-null  object
#  16  Light_conditions             12316 non-null  object
#  17  Weather_conditions           12316 non-null  object
#  18  Type_of_collision            12161 non-null  object
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12008 non-null  object
#  22  Pedestrian_movement          12316 non-null  object
#  23  Cause_of_accident            12316 non-null  object
#  24  Accident_severity            12316 non-null  object
# dtypes: int32(2), int64(4), object(19)
# memory usage: 2.3+ MB

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df['Owner_of_vehicle']=df['Owner_of_vehicle'].fillna('Other')

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', 'Other', 'Organization'], dtype=object)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation  Driving_experience  \
# 0   Above high school                Employee                   2
# 1  Junior high school                Employee                   5
# 2  Junior high school                Employee                   2
# 3  Junior high school                Employee                   4
# 4  Junior high school                Employee                   3
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                Other            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  object
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  object
#  5   Educational_level            12316 non-null  object
#  6   Vehicle_driver_relation      12316 non-null  object
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  object
#  9   Owner_of_vehicle             12316 non-null  object
#  10  Area_accident_occured        12077 non-null  object
#  11  Lanes_or_Medians             11931 non-null  object
#  12  Road_allignment              12174 non-null  object
#  13  Types_of_Junction            11429 non-null  object
#  14  Road_surface_type            12144 non-null  object
#  15  Road_surface_conditions      12316 non-null  object
#  16  Light_conditions             12316 non-null  object
#  17  Weather_conditions           12316 non-null  object
#  18  Type_of_collision            12161 non-null  object
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12008 non-null  object
#  22  Pedestrian_movement          12316 non-null  object
#  23  Cause_of_accident            12316 non-null  object
#  24  Accident_severity            12316 non-null  object
# dtypes: int32(2), int64(4), object(19)
# memory usage: 2.3+ MB

# %%
df.iloc[:5,9:]
# Out:
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  \
# 0            Owner     Residential areas                NaN
# 1            Owner          Office areas  Undivided Two way
# 2            Owner    Recreational areas              other
# 3     Governmental          Office areas              other
# 4            Owner      Industrial areas              other
#
#                                  Road_allignment Types_of_Junction  \
# 0                 Tangent road with flat terrain       No junction
# 1                 Tangent road with flat terrain       No junction
# 2                                            NaN       No junction
# 3  Tangent road with mild grade and flat terrain           Y Shape
# 4                 Tangent road with flat terrain           Y Shape
#
#   Road_surface_type Road_surface_conditions       Light_conditions  \
# 0     Asphalt roads                     Dry               Daylight
# 1     Asphalt roads                     Dry               Daylight
# 2     Asphalt roads                     Dry               Daylight
# 3       Earth roads                     Dry  Darkness - lights lit
# 4     Asphalt roads                     Dry  Darkness - lights lit
#
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
# 1             Normal           Vehicle with vehicle collision
# 2             Normal          Collision with roadside objects
# 3             Normal           Vehicle with vehicle collision
# 4             Normal           Vehicle with vehicle collision
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
# 1                            2                     2   Going straight
# 2                            2                     2   Going straight
# 3                            2                     2   Going straight
# 4                            2                     2   Going straight
#
#   Pedestrian_movement           Cause_of_accident Accident_severity
# 0    Not a Pedestrian             Moving Backward     Slight Injury
# 1    Not a Pedestrian                  Overtaking     Slight Injury
# 2    Not a Pedestrian   Changing lane to the left    Serious Injury
# 3    Not a Pedestrian  Changing lane to the right     Slight Injury
# 4    Not a Pedestrian                  Overtaking     Slight Injury

# %%
df['Area_accident_occured'].unique()
# Out:
# array(['Residential areas', 'Office areas', '  Recreational areas',
#        ' Industrial areas', nan, 'Other', ' Church areas',
#        '  Market areas', 'Unknown', 'Rural village areas',
#        ' Outside rural areas', ' Hospital areas', 'School areas',
#        'Rural village areasOffice areas', 'Recreational areas'],
#       dtype=object)

# %%
df['Area_accident_occured'].value_counts()
# Out:
# Area_accident_occured
# Other                              3819
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
#   Recreational areas                327
#  Outside rural areas                218
#  Hospital areas                     121
#   Market areas                       63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Recreational areas                    1
# Name: count, dtype: int64

# %%
df['Area_accident_occured']=df['Area_accident_occured'].str.strip()

# %%
df['Area_accident_occured'].value_counts()
# Out:
# Area_accident_occured
# Other                              3819
# Office areas                       3451
# Residential areas                  2060
# Church areas                       1060
# Industrial areas                    456
# School areas                        415
# Recreational areas                  328
# Outside rural areas                 218
# Hospital areas                      121
# Market areas                         63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Name: count, dtype: int64

# %%
df['Area_accident_occured']=df['Area_accident_occured'].fillna('Unknown')

# %%
df['Area_accident_occured']=df['Area_accident_occured'].replace({'Unknown':'Other'})

# %%
df['Area_accident_occured'].unique()
# Out:
# array(['Residential areas', 'Office areas', 'Recreational areas',
#        'Industrial areas', 'Other', 'Church areas', 'Market areas',
#        'Rural village areas', 'Outside rural areas', 'Hospital areas',
#        'School areas', 'Rural village areasOffice areas'], dtype=object)

# %%
df.iloc[:5,10:]
# Out:
#   Area_accident_occured   Lanes_or_Medians  \
# 0     Residential areas                NaN
# 1          Office areas  Undivided Two way
# 2    Recreational areas              other
# 3          Office areas              other
# 4      Industrial areas              other
#
#                                  Road_allignment Types_of_Junction  \
# 0                 Tangent road with flat terrain       No junction
# 1                 Tangent road with flat terrain       No junction
# 2                                            NaN       No junction
# 3  Tangent road with mild grade and flat terrain           Y Shape
# 4                 Tangent road with flat terrain           Y Shape
#
#   Road_surface_type Road_surface_conditions       Light_conditions  \
# 0     Asphalt roads                     Dry               Daylight
# 1     Asphalt roads                     Dry               Daylight
# 2     Asphalt roads                     Dry               Daylight
# 3       Earth roads                     Dry  Darkness - lights lit
# 4     Asphalt roads                     Dry  Darkness - lights lit
#
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
# 1             Normal           Vehicle with vehicle collision
# 2             Normal          Collision with roadside objects
# 3             Normal           Vehicle with vehicle collision
# 4             Normal           Vehicle with vehicle collision
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
# 1                            2                     2   Going straight
# 2                            2                     2   Going straight
# 3                            2                     2   Going straight
# 4                            2                     2   Going straight
#
#   Pedestrian_movement           Cause_of_accident Accident_severity
# 0    Not a Pedestrian             Moving Backward     Slight Injury
# 1    Not a Pedestrian                  Overtaking     Slight Injury
# 2    Not a Pedestrian   Changing lane to the left    Serious Injury
# 3    Not a Pedestrian  Changing lane to the right     Slight Injury
# 4    Not a Pedestrian                  Overtaking     Slight Injury

# %%
df['Lanes_or_Medians'].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
df['Lanes_or_Medians']=df['Lanes_or_Medians'].fillna('other')

# %%
df['Lanes_or_Medians']=df['Lanes_or_Medians'].replace({'Unknown':'other'})

# %%
df['Lanes_or_Medians'].unique()
# Out:
# array(['other', 'Undivided Two way', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)'], dtype=object)

# %%
df.head()
# Out:
#    Hours  Mins Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0     17     2      Monday                   1          Male
# 1     17     2      Monday                   2          Male
# 2     17     2      Monday                   1          Male
# 3      1     6      Sunday                   1          Male
# 4      1     6      Sunday                   1          Male
#
#     Educational_level Vehicle_driver_relation  Driving_experience  \
# 0   Above high school                Employee                   2
# 1  Junior high school                Employee                   5
# 2  Junior high school                Employee                   2
# 3  Junior high school                Employee                   4
# 4  Junior high school                Employee                   3
#
#        Type_of_vehicle Owner_of_vehicle  ... Road_surface_conditions  \
# 0           Automobile            Owner  ...                     Dry
# 1  Public (> 45 seats)            Owner  ...                     Dry
# 2      Lorry (41?100Q)            Owner  ...                     Dry
# 3  Public (> 45 seats)     Governmental  ...                     Dry
# 4                Other            Owner  ...                     Dry
#
#         Light_conditions Weather_conditions  \
# 0               Daylight             Normal
# 1               Daylight             Normal
# 2               Daylight             Normal
# 3  Darkness - lights lit             Normal
# 4  Darkness - lights lit             Normal
#
#                          Type_of_collision Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                           2
# 1           Vehicle with vehicle collision                           2
# 2          Collision with roadside objects                           2
# 3           Vehicle with vehicle collision                           2
# 4           Vehicle with vehicle collision                           2
#
#   Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                    2   Going straight    Not a Pedestrian
# 1                    2   Going straight    Not a Pedestrian
# 2                    2   Going straight    Not a Pedestrian
# 3                    2   Going straight    Not a Pedestrian
# 4                    2   Going straight    Not a Pedestrian
#
#             Cause_of_accident  Accident_severity
# 0             Moving Backward      Slight Injury
# 1                  Overtaking      Slight Injury
# 2   Changing lane to the left     Serious Injury
# 3  Changing lane to the right      Slight Injury
# 4                  Overtaking      Slight Injury
#
# [5 rows x 25 columns]

# %%
df.iloc[:1,11:]
# Out:
#   Lanes_or_Medians                 Road_allignment Types_of_Junction  \
# 0            other  Tangent road with flat terrain       No junction
#
#   Road_surface_type Road_surface_conditions Light_conditions  \
# 0     Asphalt roads                     Dry         Daylight
#
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
#
#   Pedestrian_movement Cause_of_accident Accident_severity
# 0    Not a Pedestrian   Moving Backward     Slight Injury

# %%
df['Road_allignment'].unique()
# Out:
# array(['Tangent road with flat terrain', nan,
#        'Tangent road with mild grade and flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
df['Road_allignment'].mode()[0]
# Out:
# 'Tangent road with flat terrain'

# %%
df['Road_allignment']=df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])

# %%
df['Road_allignment'].unique()
# Out:
# array(['Tangent road with flat terrain',
#        'Tangent road with mild grade and flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
df.iloc[:2,12:]
# Out:
#                   Road_allignment Types_of_Junction Road_surface_type  \
# 0  Tangent road with flat terrain       No junction     Asphalt roads
# 1  Tangent road with flat terrain       No junction     Asphalt roads
#
#   Road_surface_conditions Light_conditions Weather_conditions  \
# 0                     Dry         Daylight             Normal
# 1                     Dry         Daylight             Normal
#
#                          Type_of_collision  Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                            2
# 1           Vehicle with vehicle collision                            2
#
#    Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                     2   Going straight    Not a Pedestrian
# 1                     2   Going straight    Not a Pedestrian
#
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury
# 1        Overtaking     Slight Injury

# %%
df.isna().sum()
# Out:
# Hours                            0
# Mins                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Types_of_Junction              887
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               308
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
df['Types_of_Junction'].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
df['Types_of_Junction']=df['Types_of_Junction'].fillna('Other')

# %%
df['Types_of_Junction']=df['Types_of_Junction'].replace({'Unknown':'Other'})

# %%
df['Types_of_Junction'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Types_of_Junction'].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'T Shape', 'X Shape'], dtype=object)

# %%
df.iloc[:1,13:]
# Out:
#   Types_of_Junction Road_surface_type Road_surface_conditions  \
# 0       No junction     Asphalt roads                     Dry
#
#   Light_conditions Weather_conditions  \
# 0         Daylight             Normal
#
#                          Type_of_collision  Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                            2
#
#    Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                     2   Going straight    Not a Pedestrian
#
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury

# %%
df['Road_surface_type'].unique()
# Out:
# array(['Asphalt roads', 'Earth roads', nan,
#        'Asphalt roads with some distress', 'Gravel roads', 'Other'],
#       dtype=object)

# %%
df['Road_surface_type']=df['Road_surface_type'].fillna('Other')

# %%
df['Road_surface_type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Road_surface_type'].unique()
# Out:
# array(['Asphalt roads', 'Earth roads', 'Other',
#        'Asphalt roads with some distress', 'Gravel roads'], dtype=object)

# %%
df.iloc[:1,14:]
# Out:
#   Road_surface_type Road_surface_conditions Light_conditions  \
# 0     Asphalt roads                     Dry         Daylight
#
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
#
#   Pedestrian_movement Cause_of_accident Accident_severity
# 0    Not a Pedestrian   Moving Backward     Slight Injury

# %%
df['Road_surface_conditions'].unique()
# Out:
# array(['Dry', 'Wet or damp', 'Snow', 'Flood over 3cm. deep'], dtype=object)

# %%
df['Road_surface_conditions'].isna().sum()
# Out:
# np.int64(0)

# %%
df.iloc[:1,15:]
# Out:
#   Road_surface_conditions Light_conditions Weather_conditions  \
# 0                     Dry         Daylight             Normal
#
#                          Type_of_collision  Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                            2
#
#    Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                     2   Going straight    Not a Pedestrian
#
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury

# %%
df['Light_conditions'].unique()
# Out:
# array(['Daylight', 'Darkness - lights lit', 'Darkness - no lighting',
#        'Darkness - lights unlit'], dtype=object)

# %%
df.iloc[:1,16:]
# Out:
#   Light_conditions Weather_conditions  \
# 0         Daylight             Normal
#
#                          Type_of_collision  Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                            2
#
#    Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                     2   Going straight    Not a Pedestrian
#
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Normal', 'Raining', 'Raining and Windy', 'Cloudy', 'Other',
#        'Windy', 'Snow', 'Unknown', 'Fog or mist'], dtype=object)

# %%
df['Weather_conditions']=df['Weather_conditions'].replace({'Unknown':'Other'})

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Normal', 'Raining', 'Raining and Windy', 'Cloudy', 'Other',
#        'Windy', 'Snow', 'Fog or mist'], dtype=object)

# %%
df.iloc[:1,17:]
# Out:
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
#
#   Pedestrian_movement Cause_of_accident Accident_severity
# 0    Not a Pedestrian   Moving Backward     Slight Injury

# %%
df['Type_of_collision'].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
df['Type_of_collision']=df['Type_of_collision'].fillna('Unknown')

# %%
df['Type_of_collision']=df['Type_of_collision'].replace({'Unknown':'Other'})

# %%
df['Type_of_collision'].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train'], dtype=object)

# %%
df.iloc[:1,18:]
# Out:
#                          Type_of_collision  Number_of_vehicles_involved  \
# 0  Collision with roadside-parked vehicles                            2
#
#    Number_of_casualties Vehicle_movement Pedestrian_movement  \
# 0                     2   Going straight    Not a Pedestrian
#
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury

# %%
df['Number_of_vehicles_involved'].unique()
# Out:
# array([2, 1, 3, 6, 4, 7])

# %%
df['Number_of_casualties'].unique()
# Out:
# array([2, 1, 3, 4, 6, 5, 8, 7])

# %%
df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
df['Vehicle_movement']=df['Vehicle_movement'].fillna('Other')

# %%
df['Vehicle_movement']=df['Vehicle_movement'].replace({'Unknown':'Other'})

# %%
df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Other', 'Parked',
#        'Stopping', 'Overtaking', 'Entering a junction'], dtype=object)

# %%
df.iloc[:1,21:]
# Out:
#   Vehicle_movement Pedestrian_movement Cause_of_accident Accident_severity
# 0   Going straight    Not a Pedestrian   Moving Backward     Slight Injury

# %%
df['Pedestrian_movement'].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
df['Pedestrian_movement'].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
df.drop(columns={'Pedestrian_movement'},inplace=True)

# %%
df.iloc[:1,22:]
# Out:
#   Cause_of_accident Accident_severity
# 0   Moving Backward     Slight Injury

# %%
df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
df['Cause_of_accident']=df['Cause_of_accident'].replace({'Driving at high speed':'Overspeed'})

# %%
df['Cause_of_accident']=df['Cause_of_accident'].replace({'Unknown':'Other'})

# %%
df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving to the left', 'Overturning', 'Turnover',
#        'Driving under the influence of drugs', 'Drunk driving'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  object
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  object
#  5   Educational_level            12316 non-null  object
#  6   Vehicle_driver_relation      12316 non-null  object
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  object
#  9   Owner_of_vehicle             12316 non-null  object
#  10  Area_accident_occured        12316 non-null  object
#  11  Lanes_or_Medians             12316 non-null  object
#  12  Road_allignment              12316 non-null  object
#  13  Types_of_Junction            12316 non-null  object
#  14  Road_surface_type            12316 non-null  object
#  15  Road_surface_conditions      12316 non-null  object
#  16  Light_conditions             12316 non-null  object
#  17  Weather_conditions           12316 non-null  object
#  18  Type_of_collision            12316 non-null  object
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12316 non-null  object
#  22  Cause_of_accident            12316 non-null  object
#  23  Accident_severity            12316 non-null  object
# dtypes: int32(2), int64(4), object(18)
# memory usage: 2.2+ MB

# %%
cols=['Day_of_week','Sex_of_driver','Educational_level','Vehicle_driver_relation','Type_of_vehicle','Owner_of_vehicle',
    'Area_accident_occured','Lanes_or_Medians','Road_allignment','Types_of_Junction','Road_surface_type','Road_surface_conditions'
    ,'Light_conditions','Weather_conditions','Type_of_collision','Vehicle_movement','Cause_of_accident']

# %%
df['Age_band_of_driver'].unique()
# Out:
# array([ 1,  2,  0,  3, -1])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoders=[]
for i in cols:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    encoders.append(le)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  int64
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  int64
#  5   Educational_level            12316 non-null  int64
#  6   Vehicle_driver_relation      12316 non-null  int64
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  int64
#  9   Owner_of_vehicle             12316 non-null  int64
#  10  Area_accident_occured        12316 non-null  int64
#  11  Lanes_or_Medians             12316 non-null  int64
#  12  Road_allignment              12316 non-null  int64
#  13  Types_of_Junction            12316 non-null  int64
#  14  Road_surface_type            12316 non-null  int64
#  15  Road_surface_conditions      12316 non-null  int64
#  16  Light_conditions             12316 non-null  int64
#  17  Weather_conditions           12316 non-null  int64
#  18  Type_of_collision            12316 non-null  int64
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12316 non-null  int64
#  22  Cause_of_accident            12316 non-null  int64
#  23  Accident_severity            12316 non-null  object
# dtypes: int32(2), int64(21), object(1)
# memory usage: 2.2+ MB

# %%
df['Accident_severity'].unique()
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %%
acc={
    'Slight Injury':1,
    'Serious Injury':2,
    'Fatal injury':3
}

# %%
df['Accident_severity']=df['Accident_severity'].map(acc)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  int64
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  int64
#  5   Educational_level            12316 non-null  int64
#  6   Vehicle_driver_relation      12316 non-null  int64
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  int64
#  9   Owner_of_vehicle             12316 non-null  int64
#  10  Area_accident_occured        12316 non-null  int64
#  11  Lanes_or_Medians             12316 non-null  int64
#  12  Road_allignment              12316 non-null  int64
#  13  Types_of_Junction            12316 non-null  int64
#  14  Road_surface_type            12316 non-null  int64
#  15  Road_surface_conditions      12316 non-null  int64
#  16  Light_conditions             12316 non-null  int64
#  17  Weather_conditions           12316 non-null  int64
#  18  Type_of_collision            12316 non-null  int64
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12316 non-null  int64
#  22  Cause_of_accident            12316 non-null  int64
#  23  Accident_severity            12316 non-null  int64
# dtypes: int32(2), int64(22)
# memory usage: 2.2 MB

# %%
df.isna().sum()
# Out:
# Hours                          0
# Mins                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df.corr()
# Out:
#                                 Hours      Mins  Day_of_week  \
# Hours                        1.000000 -0.051828    -0.009914
# Mins                        -0.051828  1.000000    -0.009277
# Day_of_week                 -0.009914 -0.009277     1.000000
# Age_band_of_driver          -0.012272  0.007886    -0.009150
# Sex_of_driver               -0.003239  0.002033     0.009757
# Educational_level           -0.001726 -0.007550    -0.004134
# Vehicle_driver_relation     -0.002820 -0.028475     0.004408
# Driving_experience          -0.012249 -0.016926    -0.007100
# Type_of_vehicle             -0.014708 -0.002502    -0.000021
# Owner_of_vehicle            -0.002537  0.009977     0.002456
# Area_accident_occured       -0.006703 -0.004021     0.001452
# Lanes_or_Medians            -0.003145 -0.006800    -0.000632
# Road_allignment             -0.004604  0.012403    -0.008505
# Types_of_Junction           -0.019748 -0.018108    -0.023490
# Road_surface_type            0.003123  0.004954    -0.000805
# Road_surface_conditions     -0.011697  0.011328    -0.008294
# Light_conditions            -0.193693  0.005928     0.036280
# Weather_conditions          -0.018502  0.005500    -0.000004
# Type_of_collision           -0.002543  0.003777     0.001157
# Number_of_vehicles_involved  0.023095  0.019083    -0.002303
# Number_of_casualties         0.051761  0.009764    -0.050042
# Vehicle_movement            -0.012281 -0.006153    -0.028021
# Cause_of_accident           -0.002074  0.006600     0.009939
# Accident_severity            0.018065 -0.030980     0.002730
#
#                              Age_band_of_driver  Sex_of_driver  \
# Hours                                 -0.012272      -0.003239
# Mins                                   0.007886       0.002033
# Day_of_week                           -0.009150       0.009757
# Age_band_of_driver                     1.000000       0.373135
# Sex_of_driver                          0.373135       1.000000
# Educational_level                     -0.016461       0.003518
# Vehicle_driver_relation                0.014646       0.007904
# Driving_experience                    -0.000874      -0.004448
# Type_of_vehicle                        0.004523      -0.005852
# Owner_of_vehicle                       0.001065      -0.005525
# Area_accident_occured                 -0.011987       0.002206
# Lanes_or_Medians                      -0.006135      -0.014162
# Road_allignment                        0.005682      -0.005825
# Types_of_Junction                      0.018570       0.015323
# Road_surface_type                      0.003823       0.001637
# Road_surface_conditions                0.039630       0.023881
# Light_conditions                       0.065024       0.049605
# Weather_conditions                     0.007519       0.017945
# Type_of_collision                      0.004265      -0.010775
# Number_of_vehicles_involved           -0.018891      -0.041969
# Number_of_casualties                   0.057906       0.057503
# Vehicle_movement                       0.000630       0.000879
# Cause_of_accident                      0.013147       0.002124
# Accident_severity                      0.024205       0.002756
#
#                              Educational_level  Vehicle_driver_relation  \
# Hours                                -0.001726                -0.002820
# Mins                                 -0.007550                -0.028475
# Day_of_week                          -0.004134                 0.004408
# Age_band_of_driver                   -0.016461                 0.014646
# Sex_of_driver                         0.003518                 0.007904
# Educational_level                     1.000000                -0.089444
# Vehicle_driver_relation              -0.089444                 1.000000
# Driving_experience                   -0.081645                 0.054695
# Type_of_vehicle                       0.009242                -0.000546
# Owner_of_vehicle                     -0.012529                 0.019996
# Area_accident_occured                -0.015521                 0.014122
# Lanes_or_Medians                     -0.003703                 0.010527
# Road_allignment                      -0.010075                -0.013752
# Types_of_Junction                     0.017083                -0.014706
# Road_surface_type                     0.007798                -0.003888
# Road_surface_conditions               0.011189                 0.003008
# Light_conditions                     -0.001636                 0.004481
# Weather_conditions                    0.003090                -0.007868
# Type_of_collision                    -0.011746                -0.005941
# Number_of_vehicles_involved           0.013201                 0.011129
# Number_of_casualties                  0.003866                 0.019234
# Vehicle_movement                      0.007765                 0.002112
# Cause_of_accident                     0.001672                -0.008870
# Accident_severity                     0.001227                 0.012428
#
#                              Driving_experience  Type_of_vehicle  \
# Hours                                 -0.012249        -0.014708
# Mins                                  -0.016926        -0.002502
# Day_of_week                           -0.007100        -0.000021
# Age_band_of_driver                    -0.000874         0.004523
# Sex_of_driver                         -0.004448        -0.005852
# Educational_level                     -0.081645         0.009242
# Vehicle_driver_relation                0.054695        -0.000546
# Driving_experience                     1.000000        -0.034548
# Type_of_vehicle                       -0.034548         1.000000
# Owner_of_vehicle                      -0.004421        -0.004565
# Area_accident_occured                 -0.015178        -0.009425
# Lanes_or_Medians                      -0.002324        -0.016044
# Road_allignment                       -0.004081        -0.011316
# Types_of_Junction                      0.014766        -0.004726
# Road_surface_type                      0.020309         0.003712
# Road_surface_conditions               -0.007533         0.009922
# Light_conditions                      -0.008514        -0.005289
# Weather_conditions                    -0.003307         0.007837
# Type_of_collision                      0.001510         0.024247
# Number_of_vehicles_involved           -0.007095         0.000415
# Number_of_casualties                  -0.007644         0.005304
# Vehicle_movement                       0.002990         0.004205
# Cause_of_accident                     -0.010800        -0.004500
# Accident_severity                     -0.001634        -0.002841
#
#                              Owner_of_vehicle  ...  Road_surface_type  \
# Hours                               -0.002537  ...           0.003123
# Mins                                 0.009977  ...           0.004954
# Day_of_week                          0.002456  ...          -0.000805
# Age_band_of_driver                   0.001065  ...           0.003823
# Sex_of_driver                       -0.005525  ...           0.001637
# Educational_level                   -0.012529  ...           0.007798
# Vehicle_driver_relation              0.019996  ...          -0.003888
# Driving_experience                  -0.004421  ...           0.020309
# Type_of_vehicle                     -0.004565  ...           0.003712
# Owner_of_vehicle                     1.000000  ...          -0.003576
# Area_accident_occured               -0.061688  ...          -0.012884
# Lanes_or_Medians                     0.055476  ...          -0.022510
# Road_allignment                      0.001505  ...           0.008937
# Types_of_Junction                    0.012531  ...          -0.008510
# Road_surface_type                   -0.003576  ...           1.000000
# Road_surface_conditions              0.000938  ...          -0.001823
# Light_conditions                     0.011118  ...          -0.009332
# Weather_conditions                  -0.006992  ...           0.003145
# Type_of_collision                   -0.000969  ...          -0.013581
# Number_of_vehicles_involved          0.007713  ...          -0.003291
# Number_of_casualties                -0.003899  ...           0.005344
# Vehicle_movement                     0.023553  ...           0.001881
# Cause_of_accident                    0.017405  ...          -0.013271
# Accident_severity                    0.010770  ...           0.000166
#
#                              Road_surface_conditions  Light_conditions  \
# Hours                                      -0.011697         -0.193693
# Mins                                        0.011328          0.005928
# Day_of_week                                -0.008294          0.036280
# Age_band_of_driver                          0.039630          0.065024
# Sex_of_driver                               0.023881          0.049605
# Educational_level                           0.011189         -0.001636
# Vehicle_driver_relation                     0.003008          0.004481
# Driving_experience                         -0.007533         -0.008514
# Type_of_vehicle                             0.009922         -0.005289
# Owner_of_vehicle                            0.000938          0.011118
# Area_accident_occured                       0.000249         -0.013826
# Lanes_or_Medians                            0.009719          0.010022
# Road_allignment                            -0.000918          0.005625
# Types_of_Junction                           0.003267          0.033716
# Road_surface_type                          -0.001823         -0.009332
# Road_surface_conditions                     1.000000         -0.198447
# Light_conditions                           -0.198447          1.000000
# Weather_conditions                          0.565952         -0.092942
# Type_of_collision                           0.001024          0.013350
# Number_of_vehicles_involved                -0.023574          0.030009
# Number_of_casualties                        0.072828         -0.055116
# Vehicle_movement                           -0.011168          0.028172
# Cause_of_accident                           0.004628         -0.001183
# Accident_severity                          -0.004579         -0.025741
#
#                              Weather_conditions  Type_of_collision  \
# Hours                                 -0.018502          -0.002543
# Mins                                   0.005500           0.003777
# Day_of_week                           -0.000004           0.001157
# Age_band_of_driver                     0.007519           0.004265
# Sex_of_driver                          0.017945          -0.010775
# Educational_level                      0.003090          -0.011746
# Vehicle_driver_relation               -0.007868          -0.005941
# Driving_experience                    -0.003307           0.001510
# Type_of_vehicle                        0.007837           0.024247
# Owner_of_vehicle                      -0.006992          -0.000969
# Area_accident_occured                  0.001908           0.000187
# Lanes_or_Medians                      -0.005230           0.004184
# Road_allignment                        0.017007           0.022173
# Types_of_Junction                      0.002588           0.007165
# Road_surface_type                      0.003145          -0.013581
# Road_surface_conditions                0.565952           0.001024
# Light_conditions                      -0.092942           0.013350
# Weather_conditions                     1.000000          -0.011597
# Type_of_collision                     -0.011597           1.000000
# Number_of_vehicles_involved           -0.032443           0.006310
# Number_of_casualties                   0.031666          -0.016504
# Vehicle_movement                       0.008988           0.001779
# Cause_of_accident                     -0.003449           0.013129
# Accident_severity                     -0.015581          -0.027965
#
#                              Number_of_vehicles_involved  \
# Hours                                           0.023095
# Mins                                            0.019083
# Day_of_week                                    -0.002303
# Age_band_of_driver                             -0.018891
# Sex_of_driver                                  -0.041969
# Educational_level                               0.013201
# Vehicle_driver_relation                         0.011129
# Driving_experience                             -0.007095
# Type_of_vehicle                                 0.000415
# Owner_of_vehicle                                0.007713
# Area_accident_occured                          -0.007781
# Lanes_or_Medians                               -0.002899
# Road_allignment                                -0.000911
# Types_of_Junction                              -0.025772
# Road_surface_type                              -0.003291
# Road_surface_conditions                        -0.023574
# Light_conditions                                0.030009
# Weather_conditions                             -0.032443
# Type_of_collision                               0.006310
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.213427
# Vehicle_movement                               -0.007484
# Cause_of_accident                              -0.020477
# Accident_severity                              -0.096023
#
#                              Number_of_casualties  Vehicle_movement  \
# Hours                                    0.051761         -0.012281
# Mins                                     0.009764         -0.006153
# Day_of_week                             -0.050042         -0.028021
# Age_band_of_driver                       0.057906          0.000630
# Sex_of_driver                            0.057503          0.000879
# Educational_level                        0.003866          0.007765
# Vehicle_driver_relation                  0.019234          0.002112
# Driving_experience                      -0.007644          0.002990
# Type_of_vehicle                          0.005304          0.004205
# Owner_of_vehicle                        -0.003899          0.023553
# Area_accident_occured                   -0.010665          0.002481
# Lanes_or_Medians                        -0.000871         -0.003913
# Road_allignment                         -0.011434         -0.006910
# Types_of_Junction                       -0.045170         -0.010068
# Road_surface_type                        0.005344          0.001881
# Road_surface_conditions                  0.072828         -0.011168
# Light_conditions                        -0.055116          0.028172
# Weather_conditions                       0.031666          0.008988
# Type_of_collision                       -0.016504          0.001779
# Number_of_vehicles_involved              0.213427         -0.007484
# Number_of_casualties                     1.000000          0.005833
# Vehicle_movement                         0.005833          1.000000
# Cause_of_accident                       -0.023337          0.003408
# Accident_severity                        0.045339          0.013918
#
#                              Cause_of_accident  Accident_severity
# Hours                                -0.002074           0.018065
# Mins                                  0.006600          -0.030980
# Day_of_week                           0.009939           0.002730
# Age_band_of_driver                    0.013147           0.024205
# Sex_of_driver                         0.002124           0.002756
# Educational_level                     0.001672           0.001227
# Vehicle_driver_relation              -0.008870           0.012428
# Driving_experience                   -0.010800          -0.001634
# Type_of_vehicle                      -0.004500          -0.002841
# Owner_of_vehicle                      0.017405           0.010770
# Area_accident_occured                 0.001274           0.023256
# Lanes_or_Medians                      0.020291           0.009645
# Road_allignment                       0.002204           0.005967
# Types_of_Junction                    -0.007610           0.004238
# Road_surface_type                    -0.013271           0.000166
# Road_surface_conditions               0.004628          -0.004579
# Light_conditions                     -0.001183          -0.025741
# Weather_conditions                   -0.003449          -0.015581
# Type_of_collision                     0.013129          -0.027965
# Number_of_vehicles_involved          -0.020477          -0.096023
# Number_of_casualties                 -0.023337           0.045339
# Vehicle_movement                      0.003408           0.013918
# Cause_of_accident                     1.000000          -0.004985
# Accident_severity                    -0.004985           1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df.drop('Accident_severity',axis=1)
y=df['Accident_severity']

# %%
X.columns
# Out:
# Index(['Hours', 'Mins', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Cause_of_accident'],
#       dtype='object')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Hours                        12316 non-null  int32
#  1   Mins                         12316 non-null  int32
#  2   Day_of_week                  12316 non-null  int64
#  3   Age_band_of_driver           12316 non-null  int64
#  4   Sex_of_driver                12316 non-null  int64
#  5   Educational_level            12316 non-null  int64
#  6   Vehicle_driver_relation      12316 non-null  int64
#  7   Driving_experience           12316 non-null  int64
#  8   Type_of_vehicle              12316 non-null  int64
#  9   Owner_of_vehicle             12316 non-null  int64
#  10  Area_accident_occured        12316 non-null  int64
#  11  Lanes_or_Medians             12316 non-null  int64
#  12  Road_allignment              12316 non-null  int64
#  13  Types_of_Junction            12316 non-null  int64
#  14  Road_surface_type            12316 non-null  int64
#  15  Road_surface_conditions      12316 non-null  int64
#  16  Light_conditions             12316 non-null  int64
#  17  Weather_conditions           12316 non-null  int64
#  18  Type_of_collision            12316 non-null  int64
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12316 non-null  int64
#  22  Cause_of_accident            12316 non-null  int64
# dtypes: int32(2), int64(21)
# memory usage: 2.1 MB

# %%
X.head()
# Out:
#    Hours  Mins  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0     17     2            1                   1              1
# 1     17     2            1                   2              1
# 2     17     2            1                   1              1
# 3      1     6            3                   1              1
# 4      1     6            3                   1              1
#
#    Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                  0                        0                   2
# 1                  4                        0                   5
# 2                  4                        0                   2
# 3                  4                        0                   4
# 4                  4                        0                   3
#
#    Type_of_vehicle  Owner_of_vehicle  ...  Types_of_Junction  \
# 0                0                 3  ...                  1
# 1               11                 3  ...                  1
# 2                5                 3  ...                  1
# 3               11                 0  ...                  6
# 4                7                 3  ...                  6
#
#    Road_surface_type  Road_surface_conditions  Light_conditions  \
# 0                  0                        0                 3
# 1                  0                        0                 3
# 2                  0                        0                 3
# 3                  2                        0                 0
# 4                  0                        0                 0
#
#    Weather_conditions  Type_of_collision  Number_of_vehicles_involved  \
# 0                   2                  3                            2
# 1                   2                  7                            2
# 2                   2                  2                            2
# 3                   2                  7                            2
# 4                   2                  7                            2
#
#    Number_of_casualties  Vehicle_movement  Cause_of_accident
# 0                     2                 2                  8
# 1                     2                 2                 15
# 2                     2                 2                  0
# 3                     2                 2                  1
# 4                     2                 2                 15
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    1
# 4    1
# Name: Accident_severity, dtype: int64

# %%
y.value_counts()
# Out:
# Accident_severity
# 1    10415
# 2     1743
# 3      158
# Name: count, dtype: int64

# %%
X.tail()
# Out:
#        Hours  Mins  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 12311     16    15            6                   2              1
# 12312     18     0            3                  -1              1
# 12313     13    55            3                   3              1
# 12314     13    55            3                   1              0
# 12315     13    55            3                   1              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 12311                  4                        0                   3
# 12312                  1                        0                   4
# 12313                  4                        0                   4
# 12314                  4                        0                   5
# 12315                  4                        0                   4
#
#        Type_of_vehicle  Owner_of_vehicle  ...  Types_of_Junction  \
# 12311                4                 3  ...                  1
# 12312                0                 3  ...                  1
# 12313                1                 3  ...                  1
# 12314                5                 3  ...                  1
# 12315                7                 3  ...                  2
#
#        Road_surface_type  Road_surface_conditions  Light_conditions  \
# 12311                  0                        0                 3
# 12312                  0                        0                 3
# 12313                  0                        0                 3
# 12314                  0                        0                 0
# 12315                  0                        0                 0
#
#        Weather_conditions  Type_of_collision  Number_of_vehicles_involved  \
# 12311                   2                  7                            2
# 12312                   2                  7                            2
# 12313                   2                  7                            1
# 12314                   2                  7                            2
# 12315                   2                  7                            2
#
#        Number_of_casualties  Vehicle_movement  Cause_of_accident
# 12311                     1                 2                  9
# 12312                     1                 4                  9
# 12313                     1                 4                  1
# 12314                     1                 4                  4
# 12315                     1                 8                  1
#
# [5 rows x 23 columns]

# %%
y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Accident_severity'>

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE(random_state=42)
X,y=smote.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# Accident_severity
# 1    10415
# 2    10415
# 3    10415
# Name: count, dtype: int64

# %%
y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Accident_severity'>

# %%
X.tail()
# Out:
#        Hours  Mins  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 31240     15     4            2                   2              1
# 31241     22    30            3                   1              1
# 31242     11    16            3                   1              1
# 31243     18    57            5                   2              1
# 31244     11    10            5                   1              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 31240                  2                        1                   2
# 31241                  4                        0                   0
# 31242                  4                        0                   3
# 31243                  2                        0                   4
# 31244                  4                        0                   3
#
#        Type_of_vehicle  Owner_of_vehicle  ...  Types_of_Junction  \
# 31240                7                 2  ...                  6
# 31241                7                 3  ...                  0
# 31242                9                 3  ...                  1
# 31243                3                 3  ...                  6
# 31244                0                 2  ...                  6
#
#        Road_surface_type  Road_surface_conditions  Light_conditions  \
# 31240                  0                        3                 3
# 31241                  0                        0                 0
# 31242                  0                        0                 3
# 31243                  0                        0                 3
# 31244                  0                        0                 2
#
#        Weather_conditions  Type_of_collision  Number_of_vehicles_involved  \
# 31240                   2                  7                            2
# 31241                   2                  7                            2
# 31242                   2                  2                            2
# 31243                   2                  7                            2
# 31244                   2                  1                            2
#
#        Number_of_casualties  Vehicle_movement  Cause_of_accident
# 31240                     4                 3                 12
# 31241                     4                 2                  1
# 31242                     5                 3                  0
# 31243                     2                 2                 16
# 31244                     2                 2                  2
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.metrics import accuracy_score


from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
models=[LogisticRegression,DecisionTreeClassifier,KNeighborsClassifier,GaussianNB,RandomForestClassifier,SVC]
print_vals=[]

for i in models:
    mod=i()
    mod.fit(X_train,y_train)
    y_pred=mod.predict(X_test)
    ac=(accuracy_score(y_test,y_pred))
    # cm=(confusion_matrix(y_test,y_pred))
    # cr=(classification_report(y_test,y_pred))
    print_vals.append({'Model':i.__name__,'Score':ac})
print(pd.DataFrame(print_vals))
# Out:
# C:\Users\nalla\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                     Model     Score
# 0      LogisticRegression  0.525684
# 1  DecisionTreeClassifier  0.856137
# 2    KNeighborsClassifier  0.832453
# 3              GaussianNB  0.511442
# 4  RandomForestClassifier  0.945751
# 5                     SVC  0.670187

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9425508081293007

# %%
import pickle
pickle.dump(encoders,open('le.pkl','wb'))
pickle.dump(rf,open('rf.pkl','wb'))

# with open('le.pkl', 'wb') as file:
#     pickle.dump(label_encoders, file)
# pickle.dump(rf,open('rf.pkl','wb'))
