# %%
import pickle
import numpy as np
import pandas as pd

# %%
le_model=pickle.load(open('le.pkl','rb'))
standard_scaler=pickle.load(open('scaler.pkl','rb'))
xgb_model=pickle.load(open('xgb.pkl','rb'))

# %%
data=[2,351,139,26900,4900,6167,'ATWELL COLLEGE',5.524324354,2,2019,12,5]

# %%
data[6]=int(le_model.transform([data[6]]))
# Out:
# C:\Users\nalla\AppData\Local\Temp\ipykernel_21876\454569692.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   data[6]=int(le_model.transform([data[6]]))

# %%
data
# Out:
# [2, 351, 139, 26900, 4900, 6167, 8, 5.524324354, 2, 2019, 12, 5]

# %%
ind=[1,2,3,7,4,6]
data=np.array(data)
data=data.reshape(1,-1)
data.shape
# Out:
# (1, 12)

# %%
data
# Out:
# array([[2.00000000e+00, 3.51000000e+02, 1.39000000e+02, 2.69000000e+04,
#         4.90000000e+03, 6.16700000e+03, 8.00000000e+00, 5.52432435e+00,
#         2.00000000e+00, 2.01900000e+03, 1.20000000e+01, 5.00000000e+00]])

# %%
data[:,ind]=standard_scaler.transform(data[:,ind])
# Out:
# C:\Users\nalla\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
data
# Out:
# array([[ 2.00000000e+00, -1.39952051e-01, -6.13802017e-01,
#          6.44134395e-01,  9.66686393e-02,  6.16700000e+03,
#         -1.43140815e+00,  2.20249446e+00,  2.00000000e+00,
#          2.01900000e+03,  1.20000000e+01,  5.00000000e+00]])

# %%
print(xgb_model.predict(data)[0])
# Out:
# 378785.78
