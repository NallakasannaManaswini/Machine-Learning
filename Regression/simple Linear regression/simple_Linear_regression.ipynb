# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Salary_Data.csv")
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[ 4.1]
#  [ 1.5]
#  [ 5.1]
#  [ 1.3]
#  [ 5.3]
#  [ 9.6]
#  [ 3.2]
#  [ 4. ]
#  [ 2.2]
#  [ 8.2]
#  [ 3. ]
#  [ 6.8]
#  [ 3.7]
#  [ 4. ]
#  [10.5]
#  [ 6. ]
#  [ 7.1]
#  [ 1.1]
#  [ 3.2]
#  [10.3]
#  [ 2. ]
#  [ 9. ]
#  [ 8.7]
#  [ 3.9]]
# [[4.9]
#  [2.9]
#  [7.9]
#  [9.5]
#  [5.9]
#  [4.5]]
# [ 57081.  37731.  66029.  46205.  83088. 112635.  54445.  56957.  39891.
#  113812.  60150.  91738.  57189.  55794. 121872.  93940.  98273.  39343.
#   64445. 122391.  43525. 105582. 109431.  63218.]
# [ 67938.  56642. 101302. 116969.  81363.  61111.]

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre=reg.predict(x_test)
print(y_pre)
# Out:
# [ 72348.74519846  53511.61125108 100604.44611953 115674.15327744
#   81767.31217215  68581.31840899]

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,reg.predict(x_train),color="blue")
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,reg.predict(x_test),color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pre))
# Out:
# 0.9695039421049821

# %%
print(reg.predict([[10]]))
# Out:
# [120383.43676428]

# %%
from google.colab import drive
drive.mount('/content/drive')
